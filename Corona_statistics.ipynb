# %%
#import the library used to query a website
from urllib.request import urlopen

#specify the url
wiki = "https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_pandemic_by_country_and_territory"
wiki2 = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

#Query the website and return the html to the variable 'page'
page = urlopen(wiki)
page2 = urlopen(wiki2)

#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup

#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(page)
soup2 = BeautifulSoup(page2)

# %%
right_table=soup.find('table', class_='wikitable plainrowheaders sortable')
right_table2=soup2.find('table', class_='wikitable sortable')

# %%
A=[]

for row in right_table.findAll("tr"):
    cells = row.findAll('a')
    #print(cells)
    if len(cells)==2 or len(cells)==3 or len(cells)==4 or len(cells)==5:
        if cells[0].find(text=True) == None:
            A.append(cells[1].find(text=True))
        else:
            A.append(cells[0].find(text=True))
    
del(A[0])
del(A[-1])
A[0] = 'China'

# %%
A2=[]

for row in right_table2.findAll("tr"):
    cells = row.findAll('a')
    if len(cells)==1 or len(cells)==2 or len(cells)==3 or len(cells)==4 or len(cells)==5:
        if cells[0].find(text=True) == None:
            A2.append(cells[1].find(text=True))
        else:
            A2.append(cells[0].find(text=True))
    
del(A2[-1])

#Generate lists
B2=[]


for row in right_table2.findAll("tr"):
    cells = row.findAll("td")
    if len(cells)==6: #Only extract table body not heading
        B2.append(cells[2].find(text=True))

# %%
#Generate lists
B=[]
C=[]
D=[]

for row in right_table.findAll("tr"):
    cells = row.findAll("td")
    if len(cells)==4: #Only extract table body not heading
        B.append(cells[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))

# %%
G=[]

for i,country in enumerate(A):
    if A[i] in A2:
        idx = A2.index(A[i])
        population = B2[idx]
        G.append(population)
    else:
        G.append("-")

# %%
E=[]
F=[]
H=[]

for i in range(len(B)):
    rate = int(str(C[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8'))*100/int(str(B[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8'))
    exist = int(str(B[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8')) - int(str(C[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8')) - int(str(D[i]).replace('\n', '').replace('\r', '').replace(',', '').replace('–', '0').encode('utf8'))
    rate = round(rate, 3)
    E.append(rate)
    exist = format(exist, ',')
    F.append(exist)
    if G[i] != '-':
        rate10k = rate = int(str(B[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8'))*100000/int(str(G[i]).replace('\n', '').replace('\r', '').replace(',', '').encode('utf8'))
        rate10k = round(rate10k, 3)
        H.append(rate10k)
    else:
        H.append('-')

# %%
#import pandas to convert list to data frame

import pandas as pd


A[0] = 'China (mainland)'
A[43] = 'Hong Kong (China)'
A[64] = 'Taiwan (China)'
A[99] = 'Macau (China)'
df=pd.DataFrame(A,columns=['Location'])

df['Cases']=B

df['Deaths']=C

df['Recoveries']=D

df['Death rate (%)']=E

df['Existing cases']=F

df['Population']=G

df['Infected per 100,000']=H

df.to_excel("Corona_statistics.xlsx")


df
# Out:
#                      Location    Cases  Deaths Recoveries  Death rate (%)  \
# 0            China (mainland)  80,894
#   3,237
#     69,614
#            4.002
# 1                       Italy  31,506
#   2,503
#      2,941
#            7.945
# 2                        Iran  17,361
#   1,135
#      5,389
#            6.538
# 3                       Spain  13,910
#     624
#      1,081
#            4.486
# 4                     Germany  10,249
#      27
#         86
#            0.263
# 5                 South Korea   8,413
#      84
#      1,540
#            0.998
# 6                      France   7,730
#     175
#        602
#            2.264
# 7               United States   6,539
#     116
#        106
#            1.774
# 8                 Switzerland   2,742
#      27
#         15
#            0.985
# 9              United Kingdom   2,626
#      60
#         65
#            2.285
# 10                Netherlands   2,058
#      58
#           –           2.818
# 11                     Norway   1,527
#       6
#          1
#            0.393
# 12                    Belgium   1,486
#      10
#         14
#            0.673
# 13                    Austria   1,471
#       3
#          9
#            0.204
# 14                     Sweden   1,196
#       7
#          1
#            0.585
# 15                    Denmark   1,092
#       4
#           –           0.366
# 16                      Japan     889
#      29
#        144
#            3.262
# 17                   Malaysia     790
#       2
#         60
#            0.253
# 18           Diamond Princess     712
#       7
#        527
#            0.983
# 19                   Portugal     642
#       2
#          3
#            0.312
# 20                     Canada     598
#       8
#         12
#            1.338
# 21                  Australia     565
#       6
#         43
#            1.062
# 22             Czech Republic     464
#       0
#          3
#            0.000
# 23                      Qatar     442
#       0
#          4
#            0.000
# 24                     Israel     433
#       0
#         11
#            0.000
# 25                     Greece     387
#       5
#         14
#            1.292
# 26                    Finland     359
#       0
#         10
#            0.000
# 27                     Brazil     350
#       1
#          2
#            0.286
# 28                  Singapore     313
#       0
#        114
#            0.000
# 29                    Ireland     292
#       2
#          5
#            0.685
# ..                        ...      ...     ...        ...             ...
# 123                      Cuba       5
#       0
#          0
#            0.000
# 124                Seychelles       4
#       0
#          0
#            0.000
# 125                Kyrgyzstan       3
#       0
#          0
#            0.000
# 126                  Barbados       2
#       0
#          0
#            0.000
# 127                   Liberia       2
#       0
#          0
#            0.000
# 128                Montenegro       2
#       0
#          0
#            0.000
# 129                   Namibia       2
#       0
#          0
#            0.000
# 130               Saint Lucia       2
#       0
#          0
#            0.000
# 131                     Sudan       2
#       1
#          0
#           50.000
# 132                    Zambia       2
#       0
#          0
#            0.000
# 133       Antigua and Barbuda       1
#       0
#          0
#            0.000
# 134                     Benin       1
#       0
#          0
#            0.000
# 135                    Bhutan       1
#       0
#          0
#            0.000
# 136                   Bahamas       1
#       0
#          0
#            0.000
# 137  Central African Republic       1
#       0
#          0
#            0.000
# 138     Republic of the Congo       1
#       0
#          0
#            0.000
# 139                  Djibouti       1
#       0
#          0
#            0.000
# 140         Equatorial Guinea       1
#       0
#          0
#            0.000
# 141                  Eswatini       1
#       0
#          0
#            0.000
# 142                     Gabon       1
#       0
#          0
#            0.000
# 143                    Gambia       1
#       0
#          0
#            0.000
# 144                    Guinea       1
#       0
#          0
#            0.000
# 145                Mauritania       1
#       0
#          0
#            0.000
# 146              St. Vincent        1
#       0
#          0
#            0.000
# 147                   Somalia       1
#       0
#          0
#            0.000
# 148                  Suriname       1
#       0
#          0
#            0.000
# 149                  Tanzania       1
#       0
#          0
#            0.000
# 150                      Togo       1
#       0
#          0
#            0.000
# 151              Vatican City       1
#       0
#          0
#            0.000
# 152                     Nepal       1
#       0
#          1
#            0.000
#
#     Existing cases     Population Infected per 100,000
# 0            8,043  1,401,812,360                5.771
# 1           26,062     60,243,406               52.298
# 2           10,837     83,290,141               20.844
# 3           12,205     47,100,396               29.533
# 4           10,136     83,149,300               12.326
# 5            6,789     51,780,579               16.247
# 6            6,953     67,069,000               11.525
# 7            6,317    329,470,935                1.985
# 8            2,700      8,586,550               31.934
# 9            2,501     66,435,600                3.953
# 10           2,000     17,445,781               11.797
# 11           1,520      5,367,580               28.449
# 12           1,462     11,524,454               12.894
# 13           1,459      8,902,600               16.523
# 14           1,188     10,333,456               11.574
# 15           1,088      5,822,763               18.754
# 16             716    126,010,000                0.705
# 17             728     32,722,760                2.414
# 18             178              -                    -
# 19             637     10,276,617                6.247
# 20             578     37,961,548                1.575
# 21             516     25,649,909                2.203
# 22             461     10,681,161                4.344
# 23             438      2,747,282               16.089
# 24             422      9,173,250                 4.72
# 25             368     10,724,599                3.609
# 26             349      5,527,573                6.495
# 27             347    211,270,518                0.166
# 28             199      5,703,600                5.488
# 29             285      4,921,500                5.933
# ..             ...            ...                  ...
# 123              5     11,209,628                0.045
# 124              4         97,625                4.097
# 125              3      6,523,500                0.046
# 126              2        287,025                0.697
# 127              2      4,475,353                0.045
# 128              2        622,359                0.321
# 129              2      2,458,936                0.081
# 130              2        178,696                1.119
# 131              1     42,353,615                0.005
# 132              2     17,381,168                0.012
# 133              1         96,453                1.037
# 134              1     11,733,059                0.009
# 135              1        741,672                0.135
# 136              1        385,340                 0.26
# 137              1      5,496,011                0.018
# 138              1              -                    -
# 139              1      1,078,373                0.093
# 140              1      1,358,276                0.074
# 141              1      1,093,238                0.091
# 142              1      2,172,579                0.046
# 143              1      2,347,706                0.043
# 144              1     12,218,357                0.008
# 145              1      4,077,347                0.025
# 146              1              -                    -
# 147              1     15,893,219                0.006
# 148              1        581,372                0.172
# 149              1     55,890,747                0.002
# 150              1      7,538,000                0.013
# 151              1            799              125.156
# 152              0     29,609,623                0.003
#
# [153 rows x 8 columns]

# %%
d = {}

for i in range(len(A)):
    d[A[i]] = (B[i],C[i],D[i],E[i],F[i],G[i],H[i])

print(d)
# Out:
# {'China (mainland)': ('80,894\n', '3,237\n', '69,614\n', 4.002, '8,043', '1,401,812,360', 5.771), 'Italy': ('31,506\n', '2,503\n', '2,941\n', 7.945, '26,062', '60,243,406', 52.298), 'Iran': ('17,361\n', '1,135\n', '5,389\n', 6.538, '10,837', '83,290,141', 20.844), 'Spain': ('13,910\n', '624\n', '1,081\n', 4.486, '12,205', '47,100,396', 29.533), 'Germany': ('10,249\n', '27\n', '86\n', 0.263, '10,136', '83,149,300', 12.326), 'South Korea': ('8,413\n', '84\n', '1,540\n', 0.998, '6,789', '51,780,579', 16.247), 'France': ('7,730\n', '175\n', '602\n', 2.264, '6,953', '67,069,000', 11.525), 'United States': ('6,539\n', '116\n', '106\n', 1.774, '6,317', '329,470,935', 1.985), 'Switzerland': ('2,742\n', '27\n', '15\n', 0.985, '2,700', '8,586,550', 31.934), 'United Kingdom': ('2,626\n', '60\n', '65\n', 2.285, '2,501', '66,435,600', 3.953), 'Netherlands': ('2,058\n', '58\n', '–', 2.818, '2,000', '17,445,781', 11.797), 'Norway': ('1,527\n', '6\n', '1\n', 0.393, '1,520', '5,367,580', 28.449), 'Belgium': ('1,486\n', '10\n', '14\n', 0.673, '1,462', '11,524,454', 12.894), 'Austria': ('1,471\n', '3\n', '9\n', 0.204, '1,459', '8,902,600', 16.523), 'Sweden': ('1,196\n', '7\n', '1\n', 0.585, '1,188', '10,333,456', 11.574), 'Denmark': ('1,092\n', '4\n', '–', 0.366, '1,088', '5,822,763', 18.754), 'Japan': ('889\n', '29\n', '144\n', 3.262, '716', '126,010,000', 0.705), 'Malaysia': ('790\n', '2\n', '60\n', 0.253, '728', '32,722,760', 2.414), 'Diamond Princess': ('712\n', '7\n', '527\n', 0.983, '178', '-', '-'), 'Portugal': ('642\n', '2\n', '3\n', 0.312, '637', '10,276,617', 6.247), 'Canada': ('598\n', '8\n', '12\n', 1.338, '578', '37,961,548', 1.575), 'Australia': ('565\n', '6\n', '43\n', 1.062, '516', '25,649,909', 2.203), 'Czech Republic': ('464\n', '0\n', '3\n', 0.0, '461', '10,681,161', 4.344), 'Qatar': ('442\n', '0\n', '4\n', 0.0, '438', '2,747,282', 16.089), 'Israel': ('433\n', '0\n', '11\n', 0.0, '422', '9,173,250', 4.72), 'Greece': ('387\n', '5\n', '14\n', 1.292, '368', '10,724,599', 3.609), 'Finland': ('359\n', '0\n', '10\n', 0.0, '349', '5,527,573', 6.495), 'Brazil': ('350\n', '1\n', '2\n', 0.286, '347', '211,270,518', 0.166), 'Singapore': ('313\n', '0\n', '114\n', 0.0, '199', '5,703,600', 5.488), 'Ireland': ('292\n', '2\n', '5\n', 0.685, '285', '4,921,500', 5.933), 'Slovenia': ('275\n', '1\n', '0\n', 0.364, '274', '2,094,060', 13.132), 'Estonia': ('258\n', '0\n', '1\n', 0.0, '257', '1,328,360', 19.422), 'Pakistan': ('254\n', '1\n', '2\n', 0.394, '251', '218,983,520', 0.116), 'Iceland': ('250\n', '0\n', '5\n', 0.0, '245', '364,260', 68.632), 'Romania': ('246\n', '0\n', '19\n', 0.0, '227', '19,405,156', 1.268), 'Poland': ('246\n', '5\n', '1\n', 2.033, '240', '38,386,000', 0.641), 'Bahrain': ('242\n', '1\n', '88\n', 0.413, '153', '1,543,300', 15.681), 'Chile': ('238\n', '0\n', '0\n', 0.0, '238', '19,107,216', 1.246), 'Indonesia': ('227\n', '19\n', '11\n', 8.37, '197', '266,911,900', 0.085), 'Thailand': ('212\n', '1\n', '42\n', 0.472, '169', '66,482,792', 0.319), 'Luxembourg': ('203\n', '2\n', '0\n', 0.985, '201', '613,894', 33.068), 'Egypt': ('196\n', '6\n', '32\n', 3.061, '158', '100,138,465', 0.196), 'Philippines': ('193\n', '14\n', '4\n', 7.254, '175', '108,420,484', 0.178), 'Hong Kong (China)': ('181\n', '4\n', '92\n', 2.21, '85', '7,500,700', 2.413), 'Saudi Arabia': ('171\n', '0\n', '6\n', 0.0, '165', '34,218,169', 0.5), 'Iraq': ('164\n', '12\n', '41\n', 7.317, '111', '39,127,900', 0.419), 'Ecuador': ('155\n', '2\n', '0\n', 1.29, '153', '17,446,584', 0.888), 'India': ('147\n', '3\n', '14\n', 2.041, '130', '1,359,933,123', 0.011), 'Russia': ('147\n', '0\n', '5\n', 0.0, '142', '146,745,098', 0.1), 'Lebanon': ('133\n', '4\n', '4\n', 3.008, '125', '6,825,442', 1.949), 'Kuwait': ('130\n', '0\n', '15\n', 0.0, '115', '4,420,110', 2.941), 'San Marino': ('119\n', '11\n', '4\n', 9.244, '104', '33,574', 354.441), 'Peru': ('117\n', '0\n', '1\n', 0.0, '116', '32,131,400', 0.364), 'South Africa': ('116\n', '0\n', '0\n', 0.0, '116', '58,775,022', 0.197 ...
